# %%
#1 Вивести перших 5 рядків.
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#2. Визначити розмір датасета.
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print("\nРозмір датасету (рядки, стовпці):", df.shape)
# Out:
# Розмір датасету (рядки, стовпці): (418, 12)

# %%
#3. Визначити тип даних.
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print("\nТипи даних:")
print(df.dtypes)
# Out:
# Типи даних:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#4. Визначити наявність пропущених значень. При наявності, замінити
#пропущені значення на середнє значення.
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print("\nПеревірка на пропущені значення:")
print(df.isnull().sum())

df['Age'].fillna(df['Age'].mean(), inplace=True)

df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# Перевірка на пропущені значення:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# C:\Users\westw\AppData\Local\Temp\ipykernel_26024\4287857583.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\westw\AppData\Local\Temp\ipykernel_26024\4287857583.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
#5. Ще раз перевірити наявність пропущених значень.
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print("\nПеревірка на пропущені значення:")
print(df.isnull().sum())

df['Age'].fillna(df['Age'].mean(), inplace=True)

df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

print("\nПеревірка на пропущені значення після заміни:")
print(df.isnull().sum())
# Out:
# Перевірка на пропущені значення:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
#
# Перевірка на пропущені значення після заміни:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# C:\Users\westw\AppData\Local\Temp\ipykernel_26024\3188211440.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\westw\AppData\Local\Temp\ipykernel_26024\3188211440.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
#6. Перевірити наявність дублікатів. При наявності видалити дублікати.
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print("\nПеревірка на дублікатів:")
print("Кількість дублікатів:", df.duplicated().sum())

df.drop_duplicates(inplace=True)
# Out:
# Перевірка на дублікатів:
# Кількість дублікатів: 0

# %%
#7. Вивести описову статистику датасету describe()
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)
print("\nОписова статистика:")
print(df.describe())
# Out:
# Описова статистика:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#8. Видалити стовпчик Cabin
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)

df.drop('Cabin', axis=1, inplace=True)
print("\nВидалено стовпчик 'Cabin'.")
print(df)
# Out:
# Видалено стовпчик 'Cabin'.
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# 3                315154    8.6625        S
# 4               3101298   12.2875        S
# ..                  ...       ...      ...
# 413           A.5. 3236    8.0500        S
# 414            PC 17758  108.9000        C
# 415  SOTON/O.Q. 3101262    7.2500        S
# 416              359309    8.0500        S
# 417                2668   22.3583        C
#
# [418 rows x 11 columns]

# %%
#9. Сформувати датасет з обраними стовпцями:
#['Survived', 'Pclass', 'Sex', 'Age', 'Fare']
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)

df_selected = df[['Survived', 'Pclass', 'Sex', 'Age', 'Fare']]
print("\nВибрані стовпці:")
print(df_selected.head())
# Out:
# Вибрані стовпці:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  34.5   7.8292
# 1         1       3  female  47.0   7.0000
# 2         0       2    male  62.0   9.6875
# 3         0       3    male  27.0   8.6625
# 4         1       3  female  22.0  12.2875

# %%
#10.Замінити бінарні ознаки (Стать) на 0 і 1 (але перевірте унікальні
#значення даного стовпчика).
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)

print("\nУнікальні значення в стовпці 'Sex':", df['Sex'].unique())

df_selected['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
# Out:
# Унікальні значення в стовпці 'Sex': ['male' 'female']

# %%
#11.Ще раз перевірити кількість пропущених даних (впевнитись, що їх
#немає).
import pandas as pd
path = "./titanic.csv"
df = pd.read_csv(path)

print("\nУнікальні значення в стовпці 'Sex':", df['Sex'].unique())

df_selected['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
print("\nПропущені значення в новому датасеті:")
print(df_selected.isnull().sum())
# Out:
# Унікальні значення в стовпці 'Sex': ['male' 'female']
#
# Пропущені значення в новому датасеті:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# Fare         1
# dtype: int64

# %%
#12.Вивести 5 перших рядків датасету.
print("\nПерші 5 рядків:")
print(df_selected.head())
# Out:
# Перші 5 рядків:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    0  34.5   7.8292
# 1         1       3    1  47.0   7.0000
# 2         0       2    0  62.0   9.6875
# 3         0       3    0  27.0   8.6625
# 4         1       3    1  22.0  12.2875

# %%
#13.Вивести 5 останніх рядків датасету.
print("\nОстанні 5 рядків:")
print(df_selected.tail())
# Out:
# Останні 5 рядків:
#      Survived  Pclass  Sex   Age      Fare
# 413         0       3    0   NaN    8.0500
# 414         1       1    1  39.0  108.9000
# 415         0       3    0  38.5    7.2500
# 416         0       3    0   NaN    8.0500
# 417         0       3    0   NaN   22.3583

# %%
#14.Аналіз виживання залежно від статі: Обчисліть відсоток виживання
#для кожної статі. Чи була різниця у виживанні між чоловіками та
#жінками?
import seaborn as sns
import matplotlib.pyplot as plt
print("\nВиживання за статтю:")
print(df.groupby('Sex')['Survived'].mean() * 100)

sns.barplot(x='Sex', y='Survived', data=df)
plt.title("Виживання за статтю")
plt.show()
# Out:
# Виживання за статтю:
# Sex
# female    100.0
# male        0.0
# Name: Survived, dtype: float64

# %%
#15.Обчисліть відсоток виживання для кожного класу (Pclass). Який
#клас мав найвищий рівень виживання (дати відповідь)?
print("\nВиживання за класом:")
print(df.groupby('Pclass')['Survived'].mean() * 100)

sns.barplot(x='Pclass', y='Survived', data=df)
plt.title("Виживання за класом")
plt.show()
# Out:
# Виживання за класом:
# Pclass
# 1    46.728972
# 2    32.258065
# 3    33.027523
# Name: Survived, dtype: float64

# %%
#16. Визначте середній вік тих, хто вижив, і тих, хто не вижив. Чи
#впливає вік на виживання (дати відповідь)?
print("\nСередній вік виживших та не виживших:")
print(df.groupby('Survived')['Age'].mean())

sns.violinplot(x='Survived', y='Age', data=df)
plt.title("Розподіл віку серед виживших та не виживших")
plt.show()
# Out:
# Середній вік виживших та не виживших:
# Survived
# 0    30.272732
# 1    30.272362
# Name: Age, dtype: float64

# %%
#17. Розподіліть пасажирів на групи за рівнями тарифів (Fare) і
#обчисліть рівень виживання для кожної групи. Як тариф впливав на
#шанси виживання (дати відповідь)?
df['Fare_Group'] = pd.qcut(df['Fare'], 4)
print("\nВиживання за рівнем тарифів:")
print(df.groupby('Fare_Group')['Survived'].mean() * 100)

sns.barplot(x='Fare_Group', y='Survived', data=df)
plt.title("Виживання за рівнем тарифів")
plt.show()
# Out:
# Виживання за рівнем тарифів:
# Fare_Group
# (-0.001, 7.896]    26.315789
# (7.896, 14.454]    27.083333
# (14.454, 31.5]     39.047619
# (31.5, 512.329]    53.921569
# Name: Survived, dtype: float64
# C:\Users\westw\AppData\Local\Temp\ipykernel_26024\2333070998.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('Fare_Group')['Survived'].mean() * 100)

# %%
#18.Аналіз класу та тарифу: Визначте середній тариф (Fare) для кожного
#класу (Pclass). Чи існує значна різниця у тарифах між класами (дати
#відповідь)?
print("\nСередній тариф для кожного класу:")
print(df.groupby('Pclass')['Fare'].mean())

sns.barplot(x='Pclass', y='Fare', data=df)
plt.title("Середній тариф для кожного класу")
plt.show()
# Out:
# Середній тариф для кожного класу:
# Pclass
# 1    94.280297
# 2    22.202104
# 3    12.459678
# Name: Fare, dtype: float64

# %%
#19. Обчисліть середній вік пасажирів для кожного класу (Pclass). Як вік
#пасажирів розподіляється за класами (дати відповідь)?
print("\nСередній вік пасажирів для кожного класу:")
print(df.groupby('Pclass')['Age'].mean())

sns.barplot(x='Pclass', y='Age', data=df)
plt.title("Середній вік пасажирів за класами")
plt.show()
# Out:
# Середній вік пасажирів для кожного класу:
# Pclass
# 1    40.918367
# 2    28.777500
# 3    24.027945
# Name: Age, dtype: float64

# %%
#20.Побудуйте гістограму розподілу віку для тих, хто вижив, і тих, хто
#не вижив. Чи є видимі відмінності у вікових групах (дати
#відповідь)?
sns.histplot(df[df['Survived'] == 1]['Age'], color='green', label='Виживші', kde=True)
sns.histplot(df[df['Survived'] == 0]['Age'], color='red', label='Не виживші', kde=True)
plt.title("Розподіл віку серед виживших та не виживших")
plt.legend()
plt.show()

# %%
#21. Обчисліть відсоток виживання для кожної комбінації статі та класу
#(наприклад, жінки в 1-му класі, чоловіки в 3-му класі). Яка група
#мала найвищий рівень виживання (дати відповідь)?
print("\nВиживання за комбінацією статі та класу:")
print(df.groupby(['Sex', 'Pclass'])['Survived'].mean() * 100)

# Графік
sns.catplot(x="Pclass", y="Survived", hue="Sex", data=df, kind="bar")
plt.title("Виживання за статтю та класом")
plt.show()
# Out:
# Виживання за комбінацією статі та класу:
# Sex     Pclass
# female  1         100.0
#         2         100.0
#         3         100.0
# male    1           0.0
#         2           0.0
#         3           0.0
# Name: Survived, dtype: float64

# %%
#22.Обчисліть кореляцію між усіма числовими змінними (Survived,
#Pclass, Age, Fare). Які змінні найбільш сильно корелюють з
#виживанням (дати відповідь)?
print("\nКореляція між числовими змінними:")
correlation_matrix = df[['Survived', 'Pclass', 'Age', 'Fare']].corr()
print(correlation_matrix)

# Графік
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Кореляція між числовими змінними")
plt.show()
# Out:
# Кореляція між числовими змінними:
#           Survived    Pclass       Age      Fare
# Survived  1.000000 -0.108615 -0.000013  0.191514
# Pclass   -0.108615  1.000000 -0.492143 -0.577147
# Age      -0.000013 -0.492143  1.000000  0.337932
# Fare      0.191514 -0.577147  0.337932  1.000000
